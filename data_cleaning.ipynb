# %% [markdown]
# <a href="https://colab.research.google.com/github/ervinaputri/crawn-data/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv

# Set the URL for the API
url = "http://universities.hipolabs.com/search?country=United+States"

# Make the GET request
response = requests.get(url)

# Check for a successful response
if response.status_code == 200:
    data = response.json()  # Parse the JSON response

    # Specify the CSV file path
    csv_file_path = 'universities_us.csv'

    # Write to CSV
    with open(csv_file_path, mode='w', newline='', encoding='utf-8') as csv_file:
        writer = csv.writer(csv_file)

        # Write the header
        writer.writerow(['name', 'alpha_two_code', 'web_page', 'country'])

        # Write each university's data
        for university in data:
            writer.writerow([
                university.get('name'),
                university.get('alpha_two_code'),
                university.get('web_pages')[0] if university.get('web_pages') else '',
                university.get('country')
            ])

    print(f'Data has been written to {csv_file_path}')
else:
    print(f'Error: {response.status_code} - {response.text}')
# Out:
# Data has been written to universities_us.csv

# %%
import pandas as pd

df = pd.read_csv('universities_us.csv')
display(df)
# Out:
#                                        name alpha_two_code  \
# 0                       Marywood University             US
# 1                     Lindenwood University             US
# 2                       Sullivan University             US
# 3     Florida State College at Jacksonville             US
# 4                         Xavier University             US
# ...                                     ...            ...
# 2330                 Western Nevada College             US
# 2331  Western University of Health Sciences             US
# 2332                  St. Mary's University             US
# 2333            South Florida State College             US
# 2334                    Alvernia University             US
#
#                            web_page        country
# 0           http://www.marywood.edu  United States
# 1        http://www.lindenwood.edu/  United States
# 2             https://sullivan.edu/  United States
# ...

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ## Mendeteksi duplikat

# %%
df_cleaned = df.drop_duplicates(subset=['name', 'web_page'])
df_cleaned
# Out:
#                                        name alpha_two_code  \
# 0                       Marywood University             US
# 1                     Lindenwood University             US
# 2                       Sullivan University             US
# 3     Florida State College at Jacksonville             US
# 4                         Xavier University             US
# ...                                     ...            ...
# 2330                 Western Nevada College             US
# 2331  Western University of Health Sciences             US
# 2332                  St. Mary's University             US
# 2333            South Florida State College             US
# 2334                    Alvernia University             US
#
#                            web_page        country
# 0           http://www.marywood.edu  United States
# 1        http://www.lindenwood.edu/  United States
# 2             https://sullivan.edu/  United States
# ...

# %% [markdown]
# ## Membersihkan URL (Standarisasi)

# %%
df_cleaned['web_page'] = df_cleaned['web_page'].str.rstrip('/')
df_cleaned
# Out:
#                                        name alpha_two_code  \
# 0                       Marywood University             US
# 1                     Lindenwood University             US
# 2                       Sullivan University             US
# 3     Florida State College at Jacksonville             US
# 4                         Xavier University             US
# ...                                     ...            ...
# 2330                 Western Nevada College             US
# 2331  Western University of Health Sciences             US
# 2332                  St. Mary's University             US
# 2333            South Florida State College             US
# 2334                    Alvernia University             US
#
#                           web_page        country
# 0          http://www.marywood.edu  United States
# 1        http://www.lindenwood.edu  United States
# 2             https://sullivan.edu  United States
# 3             https://www.fscj.edu  United States
# ...

# %% [markdown]
# ## export data yang sudah di cleaning

# %%
# Menyimpan data yang sudah dibersihkan ke CSV
df_cleaned.to_csv('data/universities_us_cleaned.csv', index=False)

# %%
data = pd.read_csv('data/universities_us_cleaned.csv')
data
# Out:
#                                        name alpha_two_code  \
# 0                       Marywood University             US
# 1                     Lindenwood University             US
# 2                       Sullivan University             US
# 3     Florida State College at Jacksonville             US
# 4                         Xavier University             US
# ...                                     ...            ...
# 2330                 Western Nevada College             US
# 2331  Western University of Health Sciences             US
# 2332                  St. Mary's University             US
# 2333            South Florida State College             US
# 2334                    Alvernia University             US
#
#                           web_page        country
# 0          http://www.marywood.edu  United States
# 1        http://www.lindenwood.edu  United States
# 2             https://sullivan.edu  United States
# 3             https://www.fscj.edu  United States
# ...
